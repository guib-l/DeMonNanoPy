# %% [markdown]
# # Tutorial n°3
#
# ## Harmonic spectra of Coronene monomer and dimer

# %% [markdown]
# ### A. Optimization

# %%
import deMonPy

deMonPy.configure_from_file("../global.json")

# %%
from deMonPy.molden import read_XYZ

images, comm = read_XYZ("./data/coronene.xyz")
coro = images[-1]
# Out:
#  ✅ Loaded 1 elements from XYZ file.

# %%
from deMonPy.deMonNano import deMonNano

WORKDIR = ".run/tutorial-3/A/"

parameters = {
    "DEMON_EXECUTABLE": EXECUTABLE,
    "BASIS": {"PTYPE": "BIO", "SKFILE": BASIS},
    "DEMON_PARAMETERS": {
        "ACTIVE": {
            "DFTB": {"SCC": True},
        },
    },
    "DEMON_MODULE": {"ACTIVE": {"OPT": {"MAX": 9999, "OUT": 1, "TRAJECTORY": True}}},
}

dem = deMonNano(title="CALCULATION DEMONANO", workdir=WORKDIR, **parameters)

dem.calculate(symbols=coro.symbols, positions=coro.positions)
# Out:
#  ✅ Loaded 14 elements from XYZ file.

# %%
from ase.visualize import view

# view(dem.results["trajectory"])

# %% [markdown]
# ### B. Frequencies analysis

# %%
optimized_geometry = dem.results["output_geometry"]
print("Optimized geometry : ", optimized_geometry)
# Out:
# Optimized geometry :  Atoms(symbols='C24H12', pbc=False, initial_charges=...)

# %%
from deMonPy.deMonNano import deMonNano

WORKDIR = ".run/tutorial-3/B/"

parameters = {
    "DEMON_EXECUTABLE": EXECUTABLE,
    "BASIS": {"PTYPE": "BIO", "SKFILE": BASIS},
    "DEMON_PARAMETERS": {
        "ACTIVE": {"DFTB": {"SCC": True}, "FREQ": True},
    },
}

dem = deMonNano(title="CALCULATION DEMONANO", workdir=WORKDIR, **parameters)

dem.calculate(symbols=coro.symbols, positions=coro.positions)

# %%
import numpy as np

results = dem.results

freq = np.array([res["frequency"] for res in results["frequency"]])

print("Available frequencies in coronene : \n", freq)
# Out:
# Available frequencies in coronene :
#  [  79.5   79.5  108.8  150.3  210.2  276.2  276.2  279.1  279.1  372.9
#   372.9  395.2  395.3  420.3  420.3  485.   502.3  505.3  505.5  511.
#   511.   512.8  556.6  582.9  622.7  633.6  633.6  650.4  700.   715.5
#   715.5  734.8  734.8  737.3  773.5  773.5  781.9  802.8  802.8  805.
#   805.   818.4  887.6  889.7  889.7  894.1  894.1  898.6  917.1  917.1
#   958.2 1089.5 1089.6 1115.7 1154.9 1155.3 1157.3 1167.4 1167.6 1220.4
#  1254.7 1256.6 1256.8 1294.7 1332.4 1332.5 1398.5 1453.7 1453.7 1480.9
#  1546.4 1546.5 1552.9 1600.3 1642.  1642.1 1643.6 1643.7 1661.9 1662.
#  1693.4 1693.4 1726.3 1756.5 1790.7 1808.3 1838.2 1838.2 1850.  1850.
#  3032.1 3032.5 3032.7 3033.3 3033.4 3033.7 3046.5 3046.7 3046.9 3047.1
#  3047.2 3047.3   -0.     0.    -0.    -0.    -0.    -0. ]

# %% [markdown]
# ### C. Dimer of coronene

# %%
shift_coronene = optimized_geometry.copy()
shift_coronene.positions[:, 1] += 3.35
dimer = optimized_geometry + shift_coronene

# %%
from deMonPy.deMonNano import deMonNano

WORKDIR = ".run/tutorial-3/C/"

parameters = {
    "DEMON_EXECUTABLE": EXECUTABLE,
    "BASIS": {"PTYPE": "BIO", "SKFILE": BASIS},
    "DEMON_PARAMETERS": {
        "ACTIVE": {
            "DFTB": {"SCC": True, "DISP": 2},
        },
    },
    "DEMON_MODULE": {"ACTIVE": {"OPT": {"MAX": 9999, "OUT": 1, "TRAJECTORY": True}}},
}

dem = deMonNano(title="CALCULATION DEMONANO", workdir=WORKDIR, **parameters)

dem.calculate(symbols=dimer.symbols, positions=dimer.positions)
# Out:
#  ✅ Loaded 71 elements from XYZ file.

# %%
view(dem.results["trajectory"])

optimized_geometry = dem.results["output_geometry"]
print("Optimized geometry : ", optimized_geometry)
# Out:
# Optimized geometry :  Atoms(symbols='C48H24', pbc=False, initial_charges=...)

# %% [markdown]
# ### D. Frequency on dimer of coronene

# %%
optimized_dimer = dem.results["output_geometry"]

# %%
from deMonPy.deMonNano import deMonNano

WORKDIR = ".run/tutorial-3/D/"

parameters = {
    "DEMON_EXECUTABLE": EXECUTABLE,
    "BASIS": {"PTYPE": "BIO", "SKFILE": BASIS},
    "DEMON_PARAMETERS": {
        "ACTIVE": {"DFTB": {"SCC": True, "DISP": 2}, "FREQ": True},
    },
}

dem = deMonNano(title="CALCULATION DEMONANO", workdir=WORKDIR, **parameters)

dem.calculate(symbols=optimized_dimer.symbols, positions=optimized_dimer.positions)

# %%
results = dem.results

freq = np.array([res["frequency"] for res in results["frequency"]])

print("Available frequencies in coronene : \n", freq)
# Out:
# Available frequencies in coronene :
#  [ -20.7  -20.6  -16.1   67.8   67.8   74.9   82.8   82.8  105.   105.
#   113.3  130.7  153.1  165.9  212.3  218.1  278.8  278.8  281.4  281.4
#   285.1  285.1  285.7  285.7  372.3  372.4  372.7  372.7  395.3  395.3
#   395.5  395.5  422.5  422.5  423.4  423.4  484.5  484.9  503.5  503.9
#   505.1  505.2  505.2  505.3  513.4  513.4  513.9  513.9  516.3  517.
#   555.5  555.6  582.7  582.8  624.   624.6  635.4  635.4  635.8  635.8
#   650.   650.2  699.6  699.8  715.1  715.1  715.3  715.4  735.6  735.6
#   736.9  736.9  739.1  740.8  775.1  775.1  775.7  775.7  780.4  784.2
#   802.3  802.4  802.7  802.7  806.1  806.1  807.5  807.5  819.6  821.
#   889.5  889.8  891.5  891.5  891.8  891.8  895.8  895.8  896.3  896.3
#   900.3  900.8  915.3  915.3  915.7  915.7  958.1  958.2 1088.1 1088.2
#  1088.3 1088.4 1115.6 1115.9 1155.4 1155.7 1156.  1156.2 1158.2 1158.6
#  1168.  1168.3 1168.5 1168.8 1219.5 1219.6 1255.4 1255.5 1256.5 1256.7
#  1257.  1257.1 1292.4 1293.1 1330.9 1331.  1331.7 1331.8 1393.  1394.6
#  1451.1 1451.2 1451.9 1451.9 1479.7 1480.4 1543.3 1543.3 1544.  1544.1
#  1549.1 1551.2 1593.9 1595.1 1636.9 1636.9 1637.6 1637.7 1639.9 1640.
#  1641.2 1641.3 1657.8 1657.8 1658.1 1658.2 1690.3 1690.3 1690.9 1690.9
#  1722.4 1723.4 1752.6 1752.9 1785.5 1785.8 1805.7 1806.2 1834.8 1834.8
#  1835.2 1835.2 1846.2 1846.2 1846.7 1846.7 3022.4 3022.8 3023.  3023.3
#  3023.7 3023.7 3023.8 3023.8 3024.1 3024.2 3024.3 3024.4 3037.  3037.1
#  3037.4 3037.5 3037.6 3037.8 3038.1 3038.2 3038.2 3038.3 3038.5 3039.
#    -0.    -0.     0.     0.     0.     0. ]

# %% [markdown]
# ### E. Twisted dimer of coronene

# %%
optimized_dimer.positions -= optimized_dimer.get_center_of_mass()

coro_1 = optimized_dimer[:36].copy()
coro_2 = optimized_dimer[36:].copy()

coro_2.rotate(30.0, "y")

twisted_dimer = coro_1 + coro_2

# %%
parameters = {
    "DEMON_EXECUTABLE": EXECUTABLE,
    "BASIS": {"PTYPE": "BIO", "SKFILE": BASIS},
    "DEMON_PARAMETERS": {
        "ACTIVE": {"DFTB": {"SCC": True, "DISP": 2}},
    },
}

# %%
from deMonPy.deMonNano import deMonNano

WORKDIR = ".run/tutorial-3/E/"

parameters.update(
    {"DEMON_MODULE": {"ACTIVE": {"OPT": {"MAX": 9999, "OUT": 1, "TRAJECTORY": True}}}}
)

dem = deMonNano(title="CALCULATION DEMONANO", workdir=WORKDIR, **parameters)

dem.calculate(symbols=twisted_dimer.symbols, positions=twisted_dimer.positions)
# Out:
#  ✅ Loaded 87 elements from XYZ file.

# %%
optimized_dimer = dem.results["output_geometry"]

# %%
from deMonPy.deMonNano import deMonNano

WORKDIR = ".run/tutorial-3/E/"

parameters = {
    "DEMON_EXECUTABLE": EXECUTABLE,
    "BASIS": {"PTYPE": "BIO", "SKFILE": BASIS},
    "DEMON_PARAMETERS": {
        "ACTIVE": {"DFTB": {"SCC": True, "DISP": 2}, "FREQ": True},
    },
}

dem = deMonNano(title="CALCULATION DEMONANO", workdir=WORKDIR, **parameters)

dem.calculate(symbols=optimized_dimer.symbols, positions=optimized_dimer.positions)

# %%
results = dem.results

freq = np.array([res["frequency"] for res in results["frequency"]])

print("Available frequencies in coronene : \n", freq)
# Out:
# Available frequencies in coronene :
#  [  12.2   12.5   12.6   64.    64.    70.7   85.3   85.4  101.9  101.9
#   115.6  130.1  158.   158.   216.9  216.9  279.9  279.9  283.6  283.6
#   284.6  284.6  285.1  285.1  372.6  372.6  372.6  372.6  395.4  395.4
#   395.5  395.5  422.8  422.8  423.1  423.1  484.8  484.8  503.1  504.2
#   505.1  505.2  505.2  505.3  512.3  512.3  513.7  513.7  517.   518.2
#   555.5  555.6  582.7  582.7  624.   624.   635.5  635.5  636.5  636.5
#   650.1  650.2  699.7  699.7  715.1  715.2  715.3  715.3  736.2  736.2
#   736.4  736.4  739.6  739.6  775.   775.   775.3  775.3  782.2  782.2
#   802.4  802.4  802.6  802.6  806.   806.   806.7  806.7  819.4  820.2
#   889.3  889.4  891.3  891.3  891.4  891.4  895.7  895.7  895.8  895.8
#   900.1  900.1  915.3  915.3  915.7  915.7  958.1  958.3 1088.1 1088.2
#  1088.2 1088.3 1115.3 1115.5 1155.3 1155.3 1155.6 1155.6 1158.1 1158.1
#  1167.9 1167.9 1168.  1168.1 1219.5 1219.5 1255.2 1255.2 1256.5 1256.5
#  1256.8 1256.8 1292.2 1292.8 1330.8 1330.9 1331.3 1331.4 1394.1 1394.1
#  1450.9 1450.9 1451.6 1451.6 1479.9 1479.9 1543.5 1543.5 1543.8 1543.8
#  1551.3 1551.3 1595.  1595.6 1637.1 1637.1 1637.2 1637.2 1640.5 1640.6
#  1640.6 1640.7 1657.7 1657.7 1657.8 1657.8 1690.3 1690.3 1690.5 1690.5
#  1724.1 1724.1 1752.2 1752.5 1785.6 1785.6 1805.9 1806.  1834.9 1834.9
#  1835.  1835.  1846.4 1846.4 1846.6 1846.6 3022.9 3022.9 3023.3 3023.3
#  3023.4 3023.4 3023.9 3023.9 3024.1 3024.2 3024.2 3024.5 3037.1 3037.1
#  3037.5 3037.7 3037.8 3038.2 3038.2 3038.2 3038.3 3038.3 3038.3 3039.1
#     0.     0.    -0.    -0.    -0.     0. ]
