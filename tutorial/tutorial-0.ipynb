# %% [markdown]
# # Tutorial n°0
#
# ## Basics about deMonNano

# %% [markdown]
# ### A. Base about DFTB model
#
# The Density Functional based Tight-Binding model derived from Density Functional Theory model. The energy of DFTB is expressed as
#
# $$
# E_\mathrm{DFTB} = V^{rep} + \underset{i}{\sum^\mathrm{occ}} f_i\bra{\psi_i} H^0\ket{\psi_i} + \frac{1}{2} \underset{ab}{\sum}\Delta q_a\Delta q_b \gamma_\mathrm{ab}
# $$
#
# where the first term is strictly fitted repulsive terms as a sum of paire potential. In the second terms, $H^0$ is the hamiltonian operator and $f_i$ is occupations. Molecular orbitals are expressed in a minimal basis of valence atomic orbitals $\{\phi_\mu(\textbf{r})\}$, in a linear combination of atomic orbitals
#
# $$
# \ket{\psi_i} =  \underset{\mu }{\sum} c_\mu^i \ket{\phi_\mu}
# $$
#
# The third terms in energy expression is the second order contributions to the energy.

# %% [markdown]
# ### B. Setup your calculation environment
#
# #### 1. Download deMonNano
#
# Get the tutorial documents typing :
#
# ```bash
# wget http://demon-nano.ups-tlse.fr/handson_deMonNano2025.tar.gz
#
# tar -xzvf handson_deMonNano2025.tar.gz
# vi TPvars.sh
# ```
#
# Change the correct paths to deMon and FT :
#
# ```bash
# source TPvars.sh
# cd run
# ```
#
# All the calculations are expected to be run in non-parallel : type : EXPORT OMP_NUM_THREADS=1

# %% [markdown]
# #### 2. Install DeMonNanoPy librairie
#
# Get the DeMonNanoPy from source
#
# ```bash
# git clone git@github.com:guib-l/DeMonNanoPy.git
# ```
#
# Setup environment and install dependencies it needed
#
# ```bash
# python -m venv .env
# source .env/bin/activate
# pip install -r requirements.txt
# pip install -e .
# ```

# %% [markdown]
# Choose if you prefer to keep this 2 following line at start to each file :

# %%
EXECUTABLE = "~/Téléchargements/deMonNano/deMon.static-website.x",
BASIS = "~/Téléchargements/deMonNano/basis"

# %% [markdown]
# or you define a file **global.json**

# %%
{
    "DEMON_EXECUTABLE":"~/Téléchargements/deMonNano/deMon.static-website.x",
    "DEMON_BASIS":"~/Téléchargements/deMonNano/basis"
}
# Out:
# {'DEMON_EXECUTABLE': '~/Téléchargements/deMonNano/deMon.static-website.x',
#  'DEMON_BASIS': '~/Téléchargements/deMonNano/basis'}

# %% [markdown]
# and add this line at start of your file (replace the **global.json** file location) :

# %%
import deMonPy
deMonPy.configure_from_file("../global.json")

# %% [markdown]
# ### C. First calculation
#
# Now, setup your first calculation with DeMonNanoPy :

# %%
import numpy as np

symbols = ["O","H","H","O","H","H"]
positions = np.array(
            [[1.2478,-0.5185,3.4049],
            [1.5946,-1.4204,3.3886],
            [0.9008,-0.3341,2.5062]]
        )

# %%
from deMonPy.deMonNano import deMonNano

WORKDIR = ".run/tutorial-0/"

parameters = {
        "DEMON_EXECUTABLE":deMonPy.DEMON_EXECUTABLE,
        "BASIS":{
            "PTYPE":"NSC",
            "SKFILE":deMonPy.DEMON_BASIS
        },
        "DEMON_PARAMETERS":{
            "ACTIVE":{
                "DFTB":{
                },
            },
        }
    }

dem = deMonNano(
        title="CALCULATION DEMONANO",
        workdir=WORKDIR,
        **parameters
    )

dem.calculate(
        symbols=symbols,
        positions=positions
    )

dem.print_results()
# Out:
#  ✅ Loaded 2 elements from XYZ file.
# {
#     "errors": [],
#     "properties": {
#         "scc_tolerance": null,
#         "max_scc_cycles": null,
#         "scc_mixing": null,
#         "n_atoms": 3,
#         "n_atom_types": 2,
#         "matrix_dim": 6,
#         "n_electrons": 8,
#         "n_shells": 4
#     },
#     "energy": {
#         "energy": -4.10090853,
#         "electronic_energy": -4.3600594,
#         "band_energy": -4.3600594,
#         "repulsive_energy": 0.25915088,
#         "HOMO-LUMO_gap": 20.975,
#         "HOMO_gap": 2.026
#     },
#     "tensors": {
#         "mass_center": [
#             1.24778881,
#             -0.55864353,
#             3.35370651
#         ],
#         "charge_center": [
#             3.7432,
#             -2.273,
#             9.2997
#         ],
#         "charge_monopole": 0.0,
#         "charge_dipole": [
#             0.0,
#             0.0,
#             0.0
#         ],
#         "dipole_norm": 0.0,
# ...
